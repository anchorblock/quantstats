# %%
import quantstats as qs
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start = '2010-01-01'
end = '2018-01-01'
aapl = yf.download('AAPL', start=start, end=end)['Adj Close'].pct_change()
sp500 = yf.download('^GSPC', start=start, end=end)['Adj Close'].pct_change()
# sp500.index = results['returns'].index
# qs.reports.full(aapl, benchmark = sp500, figsize=(8, 4))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
qs.reports.basic(aapl, benchmark = sp500, figsize=(12, 6))
# Out:
# <h4>Performance Metrics</h4>
#                     Benchmark    Strategy
# ------------------  -----------  ----------
# Start Period        2010-01-06   2010-01-06
# End Period          2017-12-29   2017-12-29
# Risk-Free Rate      0.0%         0.0%
# Time in Market      100.0%       100.0%
#
# Cumulative Return   135.25%      516.42%
# Active Return       0.0%         381.17%
# CAGR﹪              7.68%        17.03%
#
# Sharpe              0.8          1.03
# Prob. Sharpe Ratio  98.75%       99.81%
# Sortino             1.13         1.52
# Sortino/√2          0.8          1.07
# Omega               1.2          1.2
#
# Max Drawdown        -19.39%      -43.8%
# Longest DD Days     414          660
#
# Gain/Pain Ratio     0.16         0.2
# Gain/Pain (1M)      1.1          1.19
#
# Payoff Ratio        0.94         1.02
# Profit Factor       1.16         1.2
# Common Sense Ratio  1.11         1.27
# CPC Index           0.59         0.64
# Tail Ratio          0.96         1.06
# ...

# %%
qs.reports.full(aapl, benchmark = sp500, figsize=(12, 6))
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2010-01-06   2010-01-06
# End Period                 2017-12-29   2017-12-29
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          135.25%      516.42%
# Active Return              0.0%         381.17%
# CAGR﹪                     7.68%        17.03%
#
# Sharpe                     0.8          1.03
# Prob. Sharpe Ratio         98.75%       99.81%
# Smart Sharpe               0.78         1.01
# Sortino                    1.13         1.52
# Smart Sortino              1.11         1.48
# Sortino/√2                 0.8          1.07
# Smart Sortino/√2           0.78         1.05
# Omega                      1.2          1.2
#
# Max Drawdown               -19.39%      -43.8%
# Longest DD Days            414          660
# ...
